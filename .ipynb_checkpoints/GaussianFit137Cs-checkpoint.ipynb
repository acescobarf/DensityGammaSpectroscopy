# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy.optimize import curve_fit

# %%
def ExpGaussian(x,a0,a1,x0,A,sigma, mu):
    f= a0+a1*(x-x0)+A*np.exp(-0.5*((mu-x)/sigma)**2)
    return f 
def Gaussian(x, A,sigma, mu):
    g=A*np.exp(-0.5*((mu-x)/sigma)**2)
    return g
def GaussianArea(A,sigma): #Intensidad 
    return A*sigma*np.sqrt(2.*np.pi)

# %%
AAire137Cs=np.loadtxt('Aire_137Cs_mtime_30min.dat', unpack=True)
AArena137Cs05=np.loadtxt('Arena_05cm_137Cs_mtime_30min.dat',unpack=True)
AArena137Cs10=np.loadtxt('Arena_10cm_137Cs_mtime_30min.dat',unpack=True)
AParafina137Cs8=np.loadtxt('Parafina_08cm_137Cs_mtime_30min.dat',unpack=True)
AParafina137Cs16=np.loadtxt('Parafina_16cm_137Cs_mtime_30min.dat',unpack=True)
N=[i+1 for i in range(1024)]

# %%
plt.plot(N, AParafina137Cs16)
plt.xlim(390,470)
plt.ylim(0, 1950)
# Out:
# (0, 1950)

# %%
#p0=[a0,a1,x0,A,sigma, mu]
print('Aire')
poptA, pcovA = curve_fit(ExpGaussian, N[350:800], AAire137Cs[350:800], p0=[500, -100, 430,5700, 10, 430])
EAire137Cs=[ExpGaussian(i, poptA[0], poptA[1], poptA[2], poptA[3], poptA[4], poptA[5]) for i in range(len(N))]
print('A',poptA[3], np.sqrt(np.diag(pcovA))[3])
print('sigma',poptA[4], np.sqrt(np.diag(pcovA))[4])
print('I',GaussianArea(poptA[3],poptA[4]))
# Out:
# Aire
# ('A', 5752.2022589337867, 22.013736510096347)
# ('sigma', 11.952368917600337, 0.055447995916425172)
# ('I', 172336.81879556359)
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: invalid value encountered in sqrt
#   """
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:6: RuntimeWarning: invalid value encountered in sqrt

# %%
plt.plot(N, AAire137Cs, '.',label='Aire ${}^{22}$Na', color='black')
plt.plot(N,EAire137Cs, '--',color='grey' )
plt.text(780, 5600, 'Air ${}^{137}$Cs', color='black', 
        bbox=dict(facecolor='none', edgecolor='black', boxstyle='round,pad=1'), fontsize=13)
plt.ticklabel_format(style='sci', axis='y',scilimits=(0,0))
plt.ylim(0, 6500)
plt.xlim(0,1024)
plt.xlabel('Channel', fontsize=12)
plt.ylabel('Counts', fontsize=12)
plt.savefig("Aire137Cs.pdf")

# %%
#p0=[a0,a1,x0,A,sigma, mu]
print('Arena d=0.5 cm')
popt, pcov = curve_fit(ExpGaussian, N[350:700], AArena137Cs05[350:700], p0=[500, -10, 430,2800, 10, 430])
EArena137Cs05=[ExpGaussian(i, popt[0], popt[1], popt[2], popt[3], popt[4], popt[5]) for i in range(len(N))]
print('A',popt[3], np.sqrt(np.diag(pcov))[3])
print('sigma',popt[4], np.sqrt(np.diag(pcov))[4])
print('I',GaussianArea(popt[3],popt[4]))
# Out:
# Arena d=0.5 cm
# ('A', 2828.1095905512589, 31.244821775205967)
# ('sigma', 11.775923344826593, 0.15840994112622686)
# ('I', 83479.749791345865)

# %%
plt.plot(N, AArena137Cs05, '.',label='Aire ${}^{22}$Na', color='black')
plt.plot(N,EArena137Cs05, '--',color='grey' )
plt.text(680, 5600, '$d=5$ cm ${}^{137}$Cs', color='black', 
        bbox=dict(facecolor='none', edgecolor='black', boxstyle='round,pad=1'), fontsize=13)
plt.ticklabel_format(style='sci', axis='y',scilimits=(0,0))
plt.ylim(0, 6500)
plt.xlim(0,1024)
plt.xlabel('Channel', fontsize=12)
plt.ylabel('Counts', fontsize=12)
plt.savefig("Arena137Cs05.pdf")

# %%
#p0=[a0,a1,x0,A,sigma, mu]
print('Arena d=10cm')
popt, pcov = curve_fit(ExpGaussian, N[350:850], AArena137Cs10[350:850], p0=[400, -10, 430,1750, 10, 430])
EArena137Cs10=[ExpGaussian(i, popt[0], popt[1], popt[2], popt[3], popt[4], popt[5]) for i in range(len(N))]
print('A',popt[3], np.sqrt(np.diag(pcov))[3])
print('sigma',popt[4], np.sqrt(np.diag(pcov))[4])
print('I',GaussianArea(popt[3],popt[4]))
# Out:
# Arena d=10cm
# ('A', 1722.6425471442039, 29.491603045334454)
# ('sigma', 12.511547475014613, 0.25972187651776341)
# ('I', 54025.168727133503)
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: invalid value encountered in sqrt
#   """
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:6: RuntimeWarning: invalid value encountered in sqrt

# %%
plt.plot(N, AArena137Cs10, '.',label='Aire ${}^{22}$Na', color='black')
plt.plot(N,EArena137Cs10, '--',color='grey' )
plt.text(680, 5600, '$d=10$ cm ${}^{137}$Cs', color='black', 
        bbox=dict(facecolor='none', edgecolor='black', boxstyle='round,pad=1'), fontsize=13)
plt.ticklabel_format(style='sci', axis='y',scilimits=(0,0))
plt.ylim(0, 6500)
plt.xlim(0,1024)
plt.xlabel('Channel', fontsize=12)
plt.ylabel('Counts', fontsize=12)
plt.savefig("Arena137Cs10.pdf")

# %%
#p0=[a0,a1,x0,A,sigma, mu]
print('parafina d=8 cm')
popt, pcov = curve_fit(ExpGaussian, N[350:600], AParafina137Cs8[350:600], p0=[430, -10, 430,3000, 10, 430])
EParafina137Cs8=[ExpGaussian(i, popt[0], popt[1], popt[2], popt[3], popt[4], popt[5]) for i in range(len(N))]
print('A',popt[3], np.sqrt(np.diag(pcov))[3])
print('sigma',popt[4], np.sqrt(np.diag(pcov))[4])
print('I',GaussianArea(popt[3],popt[4]))
# Out:
# parafina d=8 cm
# ('A', 2982.0974885776873, 28.067430789850935)
# ('sigma', 11.671931812952607, 0.13405177456465422)
# ('I', 87247.805650561422)
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: invalid value encountered in sqrt
#   """
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:6: RuntimeWarning: invalid value encountered in sqrt

# %%
plt.plot(N, AParafina137Cs8, '.',label='Aire ${}^{22}$Na', color='black')
plt.plot(N,EParafina137Cs8, '--',color='grey' )
plt.text(700, 5600, '$d=8$ cm ${}^{137}$Cs', color='black', 
        bbox=dict(facecolor='none', edgecolor='black', boxstyle='round,pad=1'), fontsize=13)
plt.ticklabel_format(style='sci', axis='y',scilimits=(0,0))
plt.ylim(0, 6500)
plt.xlim(0,1024)
plt.xlabel('Channel', fontsize=12)
plt.ylabel('Counts', fontsize=12)
plt.savefig("Parafina137Cs8.pdf")

# %%
#p0=[a0,a1,x0,A,sigma, mu]
print('parafina d=16 cm ')
popt, pcov = curve_fit(ExpGaussian, N[350:600], AParafina137Cs16[350:600], p0=[430, -10, 430,1450, 10, 430])
EParafina137Cs16=[ExpGaussian(i, popt[0], popt[1], popt[2], popt[3], popt[4], popt[5]) for i in range(len(N))]
print('Parafina d=16cm, fuente 137 Cs')
print('A',popt[3], np.sqrt(np.diag(pcov))[3])
print('sigma',popt[4], np.sqrt(np.diag(pcov))[4])
print('I',GaussianArea(popt[3],popt[4]))
# Out:
# parafina d=16 cm
# Parafina d=16cm, fuente 137 Cs
# ('A', 1487.7235745785908, 27.366457907792562)
# ('sigma', 11.478000263952396, 0.25739205907390228)
# ('I', 42803.413978880795)

# %%
plt.plot(N, AParafina137Cs16, '.',label='Aire ${}^{22}$Na', color='black')
plt.plot(N,EParafina137Cs16, '--',color='grey' )
plt.text(680, 5600, '$d=16$ cm ${}^{137}$Cs', color='black', 
        bbox=dict(facecolor='none', edgecolor='black', boxstyle='round,pad=1'), fontsize=13)
plt.ticklabel_format(style='sci', axis='y',scilimits=(0,0))
plt.ylim(0, 6500)
plt.xlim(0,1024)
plt.xlabel('Channel', fontsize=12)
plt.ylabel('Counts', fontsize=12)
plt.savefig("Parafina137Cs16.pdf")
